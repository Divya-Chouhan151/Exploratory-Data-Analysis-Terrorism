# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
data=pd.read_csv("/content/globalterrorismdb_0718dist.csv", encoding="latin1")
df=pd.DataFrame(data)
print("Data succecssfully imported")
# Out:
# Data succecssfully imported
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,31,33,76,94,96,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  197000000001   1970       7     2  ...      0.0       0.0     0.0      NaN
# 1  197000000002   1970       0     0  ...      1.0       1.0     1.0      NaN
# 2  197001000001   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 3  197001000002   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 4  197001000003   1970       1     0  ...     -9.0       1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
data.tail()
# Out:
#            eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 2904  197503270005   1975       3    27  ...      1.0       0.0     1.0      NaN
# 2905  197503270006   1975       3    27  ...      1.0       0.0     1.0      NaN
# 2906  197503270007   1975       3    27  ...      0.0       0.0     0.0      NaN
# 2907  197503270008   1975       3    27  ...      1.0       1.0     1.0      NaN
# 2908  197503270009   1975       3    27  ...      NaN       NaN     NaN      NaN
#
# [5 rows x 135 columns]

# %%
data.shape
# Out:
# (67548, 135)

# %%
data.describe()
# Out:
#             eventid         iyear  ...      INT_MISC       INT_ANY
# count  4.828900e+04  48289.000000  ...  48288.000000  48288.000000
# mean   1.983985e+11   1983.919920  ...      0.151694     -2.415031
# std    5.191044e+08      5.192001  ...      0.709451      4.305133
# min    1.970000e+11   1970.000000  ...     -9.000000     -9.000000
# 25%    1.980101e+11   1980.000000  ...      0.000000     -9.000000
# 50%    1.985011e+11   1985.000000  ...      0.000000      0.000000
# 75%    1.988111e+11   1988.000000  ...      0.000000      1.000000
# max    1.991093e+11   1991.000000  ...      1.000000      1.000000
#
# [8 rows x 78 columns]

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# ## INSTEAD OF DATA WE CAN ALSO USE df because we have put Data in df

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  197000000001   1970       7     2  ...      0.0       0.0     0.0      NaN
# 1  197000000002   1970       0     0  ...      1.0       1.0     1.0      NaN
# 2  197001000001   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 3  197001000002   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 4  197001000003   1970       1     0  ...     -9.0       1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
df.tail()
# Out:
#             eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 18865  198305240006   1983       5    24  ...      0.0       0.0     0.0      NaN
# 18866  198305240007   1983       5    24  ...      0.0       0.0     0.0      NaN
# 18867  198305240008   1983       5    24  ...      0.0       0.0     0.0      NaN
# 18868  198305240009   1983       5    24  ...      0.0       0.0     0.0      NaN
# 18869  198305240010   1983       5    24  ...      NaN       NaN     NaN      NaN
#
# [5 rows x 135 columns]

# %%
df.describe()
# Out:
#             eventid         iyear  ...      INT_MISC       INT_ANY
# count  1.887000e+04  18870.000000  ...  18869.000000  18869.000000
# mean   1.978580e+11   1978.517011  ...      0.249987     -2.612963
# std    3.406406e+08      3.409654  ...      0.645339      4.518743
# min    1.970000e+11   1970.000000  ...     -9.000000     -9.000000
# 25%    1.977042e+11   1977.000000  ...      0.000000     -9.000000
# 50%    1.979101e+11   1979.000000  ...      0.000000      0.000000
# 75%    1.981082e+11   1981.000000  ...      1.000000      1.000000
# max    1.983052e+11   1986.000000  ...      1.000000      1.000000
#
# [8 rows x 79 columns]

# %%
df.shape
# Out:
# (18870, 135)

# %%
df.size
# Out:
# 2547450

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
for i in df.columns:
  print(i)
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# ...

# %% [markdown]
# ## CLEANING THE DATA

# %% [markdown]
# ## RENAME COLUMN

# %%
df = df[["iyear", "imonth", "iday", "country_txt", "region_txt",  "provstate", "city", "latitude","longitude" , "location" ,
         "summary" , "attacktype1_txt" , "targtype1_txt", "gname", "motive", "weaptype1_txt" , "nkill" , "nwound" , "addnotes" ]]

# %%
df.rename(columns = { "iyear":"Year", "imonth":"Month", "iday":"Day", "country_txt":"Country", "region_txt":"Region", 
                     "provstate":"Province/State", "city":"City", "latitude":"Latitude","longitude" : "Longitude" , "location" : "Location" , "summary":"Summary","attacktype1_txt":"Attack Type",                     
                     "targtype1_txt":"Target Type", "gname":"Group Name", "motive":"Motive", "weaptype1_txt":"Weapon Type" ,"nkill" : "Killed" , "nwound":"Wounded" ,
                     "addnotes":"Add Notes" }, inplace = True   )

# %%
df.head()
# Out:
#    Year  Month  Day             Country  ... Weapon Type Killed Wounded  Add Notes
# 0  1970      7    2  Dominican Republic  ...     Unknown    1.0     0.0        NaN
# 1  1970      0    0              Mexico  ...     Unknown    0.0     0.0        NaN
# 2  1970      1    0         Philippines  ...     Unknown    1.0     0.0        NaN
# 3  1970      1    0              Greece  ...  Explosives    NaN     NaN        NaN
# 4  1970      1    0               Japan  ...  Incendiary    NaN     NaN        NaN
#
# [5 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18870 entries, 0 to 18869
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            18870 non-null  int64
#  1   Month           18870 non-null  int64
#  2   Day             18870 non-null  int64
#  3   Country         18870 non-null  object
#  4   Region          18870 non-null  object
#  5   Province/State  18785 non-null  object
#  6   City            18870 non-null  object
#  7   Latitude        18123 non-null  float64
#  8   Longitude       18123 non-null  float64
#  9   Location        608 non-null    object
#  10  Summary         957 non-null    object
#  11  Attack Type     18870 non-null  object
#  12  Target Type     18870 non-null  object
#  13  Group Name      18870 non-null  object
#  14  Motive          688 non-null    object
#  15  Weapon Type     18870 non-null  object
#  16  Killed          15348 non-null  float64
# ...

# %%
df.shape
# Out:
# (18870, 19)

# %%
df.size
# Out:
# 358530

# %%
df.isnull().sum()
# Out:
# Year                  0
# Month                 0
# Day                   0
# Country               0
# Region                0
# Province/State       85
# City                  0
# Latitude            747
# Longitude           747
# Location          18262
# Summary           17913
# Attack Type           0
# Target Type           0
# Group Name            0
# Motive            18182
# Weapon Type           0
# Killed             3522
# Wounded            5043
# Add Notes         18168
# dtype: int64

# %%
df["Killed"] = df["Killed"].fillna(0)
df["Wounded"] = df["Wounded"].fillna(0)
df["Casualty"] = df["Killed"] + df["Wounded"]

# %%
df.describe()
# Out:
#                Year         Month  ...        Killed       Wounded
# count  18870.000000  18870.000000  ...  15348.000000  13827.000000
# mean    1978.517011      6.198781  ...      1.672335      1.423158
# std        3.409654      3.448318  ...      7.496595     10.227504
# min     1970.000000      0.000000  ...      0.000000      0.000000
# 25%     1977.000000      3.000000  ...      0.000000      0.000000
# 50%     1979.000000      6.000000  ...      0.000000      0.000000
# 75%     1981.000000      9.000000  ...      1.000000      0.000000
# max     1986.000000     12.000000  ...    422.000000    700.000000
#
# [8 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Year                  0
# Month                 0
# Day                   0
# Country               0
# Region                0
# Province/State       85
# City                  0
# Latitude            747
# Longitude           747
# Location          18262
# Summary           17913
# Attack Type           0
# Target Type           0
# Group Name            0
# Motive            18182
# Weapon Type           0
# Killed             3522
# Wounded            5043
# Add Notes         18168
# dtype: int64

# %% [markdown]
# # OBSERVATION :
# 1.Data consist of terrorist activities ranging from the year : 1970 to 1998.   Maximum number of people Wounded in an event were : 5500

# %% [markdown]
# ## VISUALIZING THE DATA

# %% [markdown]
# 1.Year wise attack

# %% [markdown]
# 1. Number of attack in each Year

# %%
df.head()
# Out:
#    Year  Month  Day             Country  ... Kill Wounded Add Notes  Casualty
# 0  1970      7    2  Dominican Republic  ...  1.0     0.0       NaN       1.0
# 1  1970      0    0              Mexico  ...  0.0     0.0       NaN       0.0
# 2  1970      1    0         Philippines  ...  1.0     0.0       NaN       1.0
# 3  1970      1    0              Greece  ...  0.0     0.0       NaN       0.0
# 4  1970      1    0               Japan  ...  0.0     0.0       NaN       0.0
#
# [5 rows x 19 columns]

# %%
attacks = df["Year"].value_counts(dropna=False).sort_index().to_frame().reset_index().rename(columns={"index":"Year","Year":"Attacks"}).set_index("Year")
attacks.head()
# Out:
#       Attacks
# Year
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581

# %%
attacks.plot(kind="bar",color="purple",figsize=(15,6),fontsize=13)
plt.title("Time line of attacks",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of attacks",fontsize=15)
plt.show()

# %% [markdown]
# 2. Total casualties killed + wounded

# %%
yc = df[["Year" , "Casualty"]].groupby("Year").sum()

# %%
yc.head()
# Out:
#       Casualty
# Year
# 1970     386.0
# 1971     255.0
# 1972     975.0
# 1973     865.0
# 1974    1404.0

# %%
yc.plot(kind="bar" , color = "green" , figsize=(15,6))
plt.title("Yearwise Casualties",fontsize=13)
plt.xlabel("Years", fontsize=13)
plt.ylabel("Number of casualties",fontsize=13)
plt.show()

# %% [markdown]
# 3. Killed in each year

# %%
yk = df[["Year" , "Killed"]].groupby("Year").sum()

# %%
yk.head()
# Out:
#        Kill
# Year
# 1970  174.0
# 1971  173.0
# 1972  566.0
# 1973  370.0
# 1974  539.0

# %% [markdown]
# 4.Wounded in each year

# %%
yw = df[["Year" , "Wounded"]].groupby("Year").sum()
yw.head()
# Out:
#       Wounded
# Year
# 1970    212.0
# 1971     82.0
# 1972    409.0
# 1973    495.0
# 1974    865.0

# %% [markdown]
# ## **Region Wise Attack**

# %% [markdown]
# 1. Distribution of terrorist attacksover regions from 1970 - 2017

# %%
reg = pd.crosstab(df.Year , df.Region)
reg.head()
# Out:
# Region  Australasia & Oceania  ...  Western Europe
# Year                           ...
# 1970                        1  ...              50
# 1971                        1  ...             125
# 1972                        8  ...             376
# 1973                        1  ...             290
# 1974                        1  ...             317
#
# [5 rows x 11 columns]

# %%
reg.plot(kind = "area" , stacked = "False" , alpha = 0.5 , figsize = (20,10))
plt.title("Region wise attacks" , fontsize = 20)
plt.xlabel("Years" , fontsize = 20)
plt.ylabel("Number of attacks" , fontsize = 20)
plt.show()

# %% [markdown]
# 2. Total terrorist attacks in each region from 1970 - 2017

# %%
regt = reg.transpose()
regt["Total"] = regt.sum(axis=1)
ra = regt["Total"].sort_values(ascending = False)
ra
# Out:
# Region
# Western Europe                 3701
# North America                  1517
# South America                   778
# Middle East & North Africa      639
# Central America & Caribbean     325
# Sub-Saharan Africa              120
# Southeast Asia                  116
# East Asia                        63
# Eastern Europe                   25
# South Asia                       17
# Australasia & Oceania            15
# Name: Total, dtype: int64

# %%
ra.plot(kind = "bar" , figsize = (15,6))
plt.title("Total number of attacks in each region from 1970-2017")
plt.xlabel("Region")
plt.ylabel("Number of attacks")
plt.show()

# %% [markdown]
# 3. Total casualties (Killed + Wounded) in each region

# %%
rc = df[["Region" , "Casualty"]].groupby("Region").sum().sort_values(by="Casualty", ascending = False)
rc
# Out:
#                              Casualty
# Region
# Central America & Caribbean   15069.0
# Middle East & North Africa    10363.0
# Western Europe                 8286.0
# South America                  3908.0
# Southeast Asia                 3510.0
# Sub-Saharan Africa             2250.0
# North America                  1067.0
# South Asia                      661.0
# East Asia                       133.0
# Eastern Europe                   68.0
# Australasia & Oceania            30.0

# %%
rc.plot(kind = "bar" , figsize = (15,6))
plt.title("Region wise casualty ")
plt.xlabel("Region")
plt.ylabel("Number of casualties")
plt.show()

# %% [markdown]
# 4. Killed in each region

# %%
rk = df[["Region" , "Killed"]].groupby("Region").sum().sort_values(by="Killed", ascending = False)
rk
# Out:
#                               Killed
# Region
# Central America & Caribbean  12822.0
# Western Europe                3445.0
# Middle East & North Africa    3258.0
# South America                 3085.0
# Southeast Asia                1331.0
# Sub-Saharan Africa            1061.0
# North America                  309.0
# South Asia                     275.0
# East Asia                       38.0
# Eastern Europe                  37.0
# Australasia & Oceania            6.0

# %% [markdown]
# 5. Wounded in each region

# %%
rw = df[["Region" , "Wounded"]].groupby("Region").sum().sort_values(by="Wounded", ascending = False)
rw
# Out:
#                              Wounded
# Region
# Middle East & North Africa    7105.0
# Western Europe                4841.0
# Central America & Caribbean   2247.0
# Southeast Asia                2179.0
# Sub-Saharan Africa            1189.0
# South America                  823.0
# North America                  758.0
# South Asia                     386.0
# East Asia                       95.0
# Eastern Europe                  31.0
# Australasia & Oceania           24.0

# %%
fig = plt.figure()
ax0 = fig.add_subplot(1,2,1)
ax1 = fig.add_subplot(1,2,2)


#Killed
rk.plot(kind = "bar" , color = "blue" , figsize = (15,6) , ax=ax0)
ax0.set_title("People killed in each region")
ax0.set_xlabel("Regions")
ax0.set_ylabel("Number of people killed")


#Wounded
rw.plot(kind = "bar" , color = "purple" , figsize = (15,6) , ax=ax1)
ax1.set_title("People wounded in each region")
ax1.set_xlabel("Regions")
ax1.set_ylabel("Number of people Wounded")


plt.show()

# %% [markdown]
# ## Country wise attack

# %%
ct =  df["Country"].value_counts().head(10)

# %%
ct
# Out:
# El Salvador       2547
# United Kingdom    2087
# United States     1711
# Spain             1374
# Italy             1226
# Guatemala         1194
# Colombia          1051
# France             781
# Peru               757
# Turkey             593
# Name: Country, dtype: int64

# %%
ct.plot(kind="bar", color="green", figsize = (15,6))
plt.title("Country wise attack",fontsize=13)
plt.xlabel("Countries",fontsize=13)
plt.ylabel("Number of attacks",fontsize=13)
# Out:
# Text(0, 0.5, 'Number of attacks')

# %% [markdown]
# 2. Total casualties (killed + wounded) in each country

# %%
cnc = df[["Country" , "Casualty"]].groupby("Country").sum().sort_values(by="Casualty", ascending = False)
cnc
# Out:
#                 Casualty
# Country
# El Salvador       7872.0
# Guatemala         4420.0
# United Kingdom    3704.0
# Lebanon           3080.0
# Iran              2889.0
# ...                  ...
# Iceland              0.0
# New Hebrides         0.0
# New Zealand          0.0
# Norway               0.0
# Luxembourg           0.0
#
# [129 rows x 1 columns]

# %%
cnc[:10].plot(kind="bar", color="green", figsize = (15,6))
plt.title("Country wise casualties",fontsize=13)
plt.xlabel("Countries",fontsize=13)
plt.ylabel("Number of casualties",fontsize=13)
# Out:
# Text(0, 0.5, 'Number of casualties')

# %% [markdown]
# 3. Killed in each country

# %%
cnk = df[["Country" , "Casualty"]].groupby("Country").sum().sort_values(by="Casualty", ascending = False)
cnk
# Out:
#                 Casualty
# Country
# United Kingdom    2964.0
# Israel            1257.0
# Spain              893.0
# Iran               821.0
# United States      773.0
# ...                  ...
# Somalia              0.0
# Tunisia              0.0
# South Yemen          0.0
# Haiti                0.0
# Chad                 0.0
#
# [108 rows x 1 columns]

# %% [markdown]
# 4. Wounded in each country

# %%
cnw = df[["Country" , "Wounded"]].groupby("Country").sum().sort_values(by="Wounded", ascending = False)
cnw
# Out:
#                 Wounded
# Country
# United Kingdom   1218.0
# Israel           1004.0
# United States     594.0
# Spain             584.0
# Italy             448.0
# ...                 ...
# Saudi Arabia        0.0
# Singapore           0.0
# Somalia             0.0
# South Korea         0.0
# Zambia              0.0
#
# [108 rows x 1 columns]

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)


#Killed
cnk[:10].plot(kind = "bar" , color = "blue" , figsize = (15,6) , ax=ax0)
ax0.set_title("People killed in each country")
ax0.set_xlabel("Countries")
ax0.set_ylabel("Number of people killed")


#Wounded
cnw[:10].plot(kind = "bar" , color = "purple" , figsize = (15,6) , ax=ax1)
ax1.set_title("People wounded in each country")
ax1.set_xlabel("Countries")
ax1.set_ylabel("Number of people Wounded")


plt.show()

# %% [markdown]
# 4. City wise attacks -  top 10

# %% [markdown]
# 1. Number of attacks in each city

# %%
city=df["City"].value_counts()[1:11]
city
# Out:
# Unknown          405
# Rome             335
# New York City    322
# Paris            234
# San Salvador     212
# Buenos Aires     199
# Madrid           199
# Ankara           142
# Istanbul         132
# Bogota           131
# Name: City, dtype: int64

# %%
city.plot(kind="bar", color="green", figsize = (15,6))
plt.title("City wise attacks",fontsize=13)
plt.xlabel("Cities",fontsize=13)
plt.ylabel("Number of attacks",fontsize=13)
# Out:
# Text(0, 0.5, 'Number of attacks')

# %% [markdown]
# 2. Total casualties (killed + wounded) in each city

# %%
cc = df[["City","Casualty"]].groupby("City").sum().sort_values(by="Casualty",ascending = False).drop("Unknown")

# %%
cc
# Out:
#                     Casualty
# City
# Belfast               1161.0
# London                 535.0
# Jerusalem              465.0
# Beirut                 435.0
# Abadan                 427.0
# ...                      ...
# L'Ile-Rousse             0.0
# La Aguada district       0.0
# La Florida               0.0
# La Herradura             0.0
# Laurel                   0.0
#
# [1821 rows x 1 columns]

# %%
cc[:10].plot(kind = "bar" , color = "blue" , figsize = (15,6))
plt.title("City wise casualties")
plt.xlabel("Cities")
plt.ylabel("Number of casualties")
plt.show()

# %% [markdown]
# 3. Killed in each city

# %%
ck = df[["City","Killed"]].groupby("City").sum().sort_values(by="Killed", ascending=False).drop("Unknown")
ck
# Out:
#               Killed
# City
# Belfast        876.0
# Abadan         422.0
# Buenos Aires   226.0
# Beirut         147.0
# San Salvador   128.0
# ...              ...
# Jesus Maria      0.0
# Jersualem        0.0
# Jericho          0.0
# Jennings         0.0
# unknown          0.0
#
# [1821 rows x 1 columns]

# %% [markdown]
# 4. Wounded in each city

# %%
cw = df[["City","Wounded"]].groupby("City").sum().sort_values(by="Wounded", ascending=False).drop("Unknown")
cw
# Out:
#              Wounded
# City
# London         499.0
# Jerusalem      428.0
# Beirut         288.0
# Belfast        285.0
# Baghdad        285.0
# ...              ...
# Glendale         0.0
# Glen Cove        0.0
# Glen Burnie      0.0
# Glasgow          0.0
# Laurel           0.0
#
# [1821 rows x 1 columns]

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)


#Killed
ck[:10].plot(kind = "bar" , color = "blue" , figsize = (15,6) , ax=ax0)
ax0.set_title("People killed in each country")
ax0.set_xlabel("Cities")
ax0.set_ylabel("Number of people killed")


#Wounded
cw[:10].plot(kind = "bar" , color = "purple" , figsize = (15,6) , ax=ax1)
ax1.set_title("People wounded in each city")
ax1.set_xlabel("Cities")
ax1.set_ylabel("Number of people Wounded")


plt.show()

# %% [markdown]
# Belfast is at  max always

# %% [markdown]
# ## 5. Terrorist group wise attack

# %% [markdown]
# 1. Number of attack by each group

# %%
grp = df["Group Name"].value_counts()[1:11]
grp
# Out:
# Irish Republican Army (IRA)                    983
# Basque Fatherland and Freedom (ETA)            424
# Protestant extremists                          197
# Sandinista National Liberation Front (FSLN)    197
# Ulster Volunteer Force (UVF)                   170
# Left-Wing Militants                            169
# Corsican National Liberation Front (FLNC)      149
# Palestinians                                   149
# Red Brigades                                   142
# People's Liberation Forces (FPL)               136
# Name: Group Name, dtype: int64

# %%
grp.plot(kind = "bar" , figsize = (15,6))
plt.title("Group wise attack")
plt.xlabel("Terrorists Group")
plt.ylabel("Number of attacks")
plt.show()

# %% [markdown]
# 2. Total casualties(Killed + Wounded) by each group

# %%
gc = df[["Group Name" , "Casualty"]].groupby("Group Name").sum().sort_values(by = "Casualty" , ascending = False)
gc
# Out:
#                                      Casualty
# Group Name
# Unknown                                2869.0
# Irish Republican Army (IRA)            2123.0
# Basque Fatherland and Freedom (ETA)     602.0
# Palestinians                            483.0
# Mujahedin-e Khalq (MEK)                 456.0
# ...                                       ...
# Greek Popular Resistance                  0.0
# Greek Anti-Dictatorial Youth (EAN)        0.0
# Gay Liberation Front                      0.0
# GAC                                       0.0
# Zimbabwe People's Army (ZIPA)             0.0
#
# [622 rows x 1 columns]

# %%
gc.head(10).plot(kind = "bar" , figsize = (15,6))
plt.title("Casualties by each Group")
plt.xlabel("Terrorists Group")
plt.ylabel("Number of Casualties")
plt.show()

# %% [markdown]
# 3. Killed by each group

# %%
gk = df[["Group Name" , "Killed"]].groupby("Group Name").sum().sort_values(by = "Killed" , ascending = False)
gk
# Out:
#                                              Killed
# Group Name
# Unknown                                      1003.0
# Irish Republican Army (IRA)                   989.0
# Mujahedin-e Khalq (MEK)                       449.0
# Ulster Volunteer Force (UVF)                  281.0
# Sandinista National Liberation Front (FSLN)   241.0
# ...                                             ...
# Fighting Communists                             0.0
# Fighting Communist Unit                         0.0
# Fighting Communist Front                        0.0
# Fighters for Communism                          0.0
# Zimbabwe People's Army (ZIPA)                   0.0
#
# [622 rows x 1 columns]

# %% [markdown]
# 4. Wounded by each group

# %%
gw = df[["Group Name" , "Wounded"]].groupby("Group Name").sum().sort_values(by = "Wounded" , ascending = False)
gw
# Out:
#                                                     Wounded
# Group Name
# Unknown                                              1866.0
# Irish Republican Army (IRA)                          1134.0
# Palestinians                                          427.0
# Basque Fatherland and Freedom (ETA)                   400.0
# Popular Front for the Liberation of Palestine (...    218.0
# ...                                                     ...
# Fronte Paesanu Corsu di Liberazione (FPCL)              0.0
# Front for the National Liberation of Puerto Rico        0.0
# Front for the Liberation of the French Somali C...      0.0
# Front for the Liberation of the Enclave of Cabi...      0.0
# Zimbabwe People's Army (ZIPA)                           0.0
#
# [622 rows x 1 columns]

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)


#Killed
gk[:10].plot(kind = "bar" , color = "blue" , figsize = (15,6) , ax=ax0)
ax0.set_title("People killed in each country")
ax0.set_xlabel("Cities")
ax0.set_ylabel("Number of people killed")


#Wounded
gw[:10].plot(kind = "bar" , color = "purple" , figsize = (15,6) , ax=ax1)
ax1.set_title("People wounded in each city")
ax1.set_xlabel("Cities")
ax1.set_ylabel("Number of people Wounded")


plt.show()

# %% [markdown]
# # 6. Attack Type wise attack

# %% [markdown]
# 1. Number of attacks by each attack type

# %%
at = df["Attack Type"].value_counts()
at
# Out:
# Bombing/Explosion                      4237
# Assassination                          1947
# Armed Assault                          1352
# Facility/Infrastructure Attack         1067
# Hostage Taking (Kidnapping)             525
# Unknown                                 278
# Hostage Taking (Barricade Incident)     163
# Hijacking                                61
# Unarmed Assault                          25
# Name: Attack Type, dtype: int64

# %%
at.plot(kind = "bar" , figsize = (15,6))
plt.title("Types of attacks")
plt.xlabel("Attack types")
plt.ylabel("Number of attacks")
plt.show()

# %% [markdown]
# 2. Total casualties (Killed + Wounded) by each attack type

# %%
ac = df[["Attack Type" , "Casualty"]].groupby("Attack Type").sum().sort_values(by = "Casualty" , ascending = False)
ac
# Out:
#                                      Casualty
# Attack Type
# Bombing/Explosion                      7840.0
# Armed Assault                          2514.0
# Assassination                          2349.0
# Facility/Infrastructure Attack          716.0
# Hostage Taking (Barricade Incident)     451.0
# Unknown                                 426.0
# Hijacking                               226.0
# Hostage Taking (Kidnapping)             219.0
# Unarmed Assault                          21.0

# %%
ac.plot(kind = "bar" , figsize = (15,6))
plt.title("Casualties in each attack" , fontsize=12)
plt.xlabel("Attack types" , fontsize=12)
plt.ylabel("Number of casualties" , fontsize=12)
plt.show()

# %% [markdown]
# 3. Killed by each attack type

# %%
ak = df[["Attack Type" , "Killed"]].groupby("Attack Type").sum().sort_values(by="Killed" , ascending = False)
ak
# Out:
#                                      Killed
# Attack Type
# Bombing/Explosion                    2083.0
# Assassination                        1923.0
# Armed Assault                        1519.0
# Facility/Infrastructure Attack        495.0
# Unknown                               346.0
# Hostage Taking (Barricade Incident)   196.0
# Hostage Taking (Kidnapping)           181.0
# Hijacking                             175.0
# Unarmed Assault                        11.0

# %% [markdown]
# 4. Wounded by each attack type

# %%
aw = df[["Attack Type" , "Wounded"]].groupby("Attack Type").sum().sort_values(by = "Wounded" , ascending = False)
aw
# Out:
#                                      Wounded
# Attack Type
# Bombing/Explosion                     5757.0
# Armed Assault                          995.0
# Assassination                          426.0
# Hostage Taking (Barricade Incident)    255.0
# Facility/Infrastructure Attack         221.0
# Unknown                                 80.0
# Hijacking                               51.0
# Hostage Taking (Kidnapping)             38.0
# Unarmed Assault                         10.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)


#Killed
ak.plot(kind = "bar" , color = "blue" , figsize = (15,6) , ax=ax0)
ax0.set_title("People killed in each attack type")
ax0.set_xlabel("Attack types")
ax0.set_ylabel("Number of people killed")


#Wounded
aw[:10].plot(kind = "bar" , color = "purple" , figsize = (15,6) , ax=ax1)
ax1.set_title("People wounded in each attack type")
ax1.set_xlabel("Attack Types")
ax1.set_ylabel("Number of people Wounded")


plt.show()

# %% [markdown]
# 7. Target typewise attack

# %% [markdown]
# 1. Number of attack over each target type

# %%
ta = df['Target Type'].value_counts()

# %%
ta
# Out:
# Business                          5271
# Military                          4423
# Private Citizens & Property       4408
# Government (General)              3174
# Police                            2769
# Utilities                         1536
# Government (Diplomatic)           1282
# Transportation                    1201
# Journalists & Media                709
# Educational Institution            642
# Airports & Aircraft                606
# Religious Figures/Institutions     365
# Terrorists/Non-State Militia       279
# Unknown                            273
# Telecommunication                  231
# Violent Political Party            115
# NGO                                 81
# Maritime                            80
# Food or Water Supply                79
# Tourists                            72
# Abortion Related                    66
# Other                                9
# Name: Target Type, dtype: int64

# %%
ta.plot(kind="bar",color="blue",figsize = (15,6))
plt.title("Type of targets",fontsize = 21)
plt.xlabel("Target type" , fontsize = 21)
plt.ylabel("Number of attacks",fontsize = 21)
# Out:
# Text(0, 0.5, 'Number of attacks')

# %%
tc = df[["Target Type" , "Casualty"]].groupby("Target Type").sum().sort_values(by="Casualty" , ascending = False)
tc
# Out:
#                                 Casualty
# Target Type
# Business                          2925.0
# Private Citizens & Property       2589.0
# Military                          1950.0
# Airports & Aircraft               1701.0
# Government (General)              1348.0
# Police                            1312.0
# Transportation                     973.0
# Educational Institution            438.0
# Government (Diplomatic)            338.0
# Violent Political Party            304.0
# Terrorists/Non-State Militia       278.0
# Journalists & Media                172.0
# Religious Figures/Institutions     170.0
# Unknown                            133.0
# Utilities                           54.0
# Maritime                            25.0
# Tourists                            24.0
# NGO                                 11.0
# Telecommunication                    9.0
# Food or Water Supply                 6.0
# Abortion Related                     2.0
# ...

# %%
tc.plot(kind="bar",color="blue",figsize = (15,6))
plt.title("Casualty in each target type",fontsize = 21)
plt.xlabel("Target type" , fontsize = 21)
plt.ylabel("Number of casualties",fontsize = 21)
# Out:
# Text(0, 0.5, 'Number of casualties')

# %%
tk = df[["Target Type" , "Killed"]].groupby("Target Type").sum().sort_values(by="Killed" , ascending = False)
tk
# Out:
#                                 Killed
# Target Type
# Private Citizens & Property     1387.0
# Military                        1340.0
# Business                        1131.0
# Airports & Aircraft              774.0
# Police                           743.0
# Government (General)             462.0
# Transportation                   265.0
# Terrorists/Non-State Militia     228.0
# Violent Political Party          122.0
# Government (Diplomatic)           98.0
# Unknown                           90.0
# Educational Institution           90.0
# Religious Figures/Institutions    71.0
# Journalists & Media               65.0
# Utilities                         25.0
# Maritime                          14.0
# Tourists                          10.0
# NGO                                9.0
# Telecommunication                  4.0
# Food or Water Supply               1.0
# Abortion Related                   0.0
# Other                              0.0

# %%
tw = df[["Target Type" , "Wounded"]].groupby("Target Type").sum().sort_values(by="Wounded" , ascending = False)
tw
# Out:
#                                 Wounded
# Target Type
# Business                         1794.0
# Private Citizens & Property      1202.0
# Airports & Aircraft               927.0
# Government (General)              886.0
# Transportation                    708.0
# Military                          610.0
# Police                            569.0
# Educational Institution           348.0
# Government (Diplomatic)           240.0
# Violent Political Party           182.0
# Journalists & Media               107.0
# Religious Figures/Institutions     99.0
# Terrorists/Non-State Militia       50.0
# Unknown                            43.0
# Utilities                          29.0
# Tourists                           14.0
# Maritime                           11.0
# Food or Water Supply                5.0
# Telecommunication                   5.0
# Abortion Related                    2.0
# NGO                                 2.0
# Other                               0.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)


#Killed
tk.plot(kind = "bar" , color = "blue" , figsize = (15,6) , ax=ax0)
ax0.set_title("People killed in each target attack")
ax0.set_xlabel("Target types")
ax0.set_ylabel("Number of people killed")


#Wounded
tw[:10].plot(kind = "bar" , color = "purple" , figsize = (15,6) , ax=ax1)
ax1.set_title("People wounded in each target attack")
ax1.set_xlabel("Target Types")
ax1.set_ylabel("Number of people Wounded")


plt.show()

# %% [markdown]
# ## 8. Group + Country wise - Top 10

# %% [markdown]
# 1. Sorting by number of attacks

# %%
gca = df[["Group Name","Country"]].value_counts().drop("Unknown")
gca.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:3889: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# Group Name                                   Country
# Irish Republican Army (IRA)                  United Kingdom    946
# Basque Fatherland and Freedom (ETA)          Spain             419
# Protestant extremists                        United Kingdom    195
# Sandinista National Liberation Front (FSLN)  Nicaragua         193
# Left-Wing Militants                          United States     169
# Ulster Volunteer Force (UVF)                 United Kingdom    165
# Corsican National Liberation Front (FLNC)    France            149
# Red Brigades                                 Italy             141
# People's Liberation Forces (FPL)             El Salvador       136
# Montoneros (Argentina)                       Argentina         114
# ...

# %%
 gca.head(10).plot(kind="bar" , color = "blue" , figsize = (15,6))
plt.title("Countries with most attacks by particular group",fo ntsize = 13)
plt.xlabel("Terrorist Group , Country" , fontsize = 13)
plt.ylabel("Number of attacks" , fontsize = 13)
# Out:
# Text(0, 0.5, 'Number of attacks')

# %% [markdown]
# 2. Sorting by Number of casualties

# %%
gcc = df[["Group Name","Country","Casualty"]].groupby(["Group Name" , "Country"],axis=0).sum()
gcc
# Out:
#                                                    Casualty
# Group Name                         Country
# 1st of May Group                   Spain                0.0
#                                    Switzerland          0.0
#                                    United Kingdom       0.0
# 23rd of September Communist League Mexico              84.0
# 28 May Armenian Organization       Turkey              57.0
# ...                                                     ...
# Zimbabwe African People's Union    Zambia               0.0
# Zimbabwe Guerrillas                Rhodesia             2.0
#                                    Zambia               0.0
# Zimbabwe Patriotic Front           Rhodesia            18.0
# Zimbabwe People's Army (ZIPA)      Rhodesia             0.0
#
# [939 rows x 1 columns]

# %% [markdown]
# 3. Sorting  by Number of people killed

# %%
gck = df[["Group Name" , "Country" , "Killed"]].groupby(["Group Name" , "Country"],axis=0).sum()
gck
# Out:
#                                                    Killed
# Group Name                         Country
# 1st of May Group                   Spain              0.0
#                                    Switzerland        0.0
#                                    United Kingdom     0.0
# 23rd of September Communist League Mexico            70.0
# 28 May Armenian Organization       Turkey             5.0
# ...                                                   ...
# Zimbabwe African People's Union    Zambia             0.0
# Zimbabwe Guerrillas                Rhodesia           0.0
#                                    Zambia             0.0
# Zimbabwe Patriotic Front           Rhodesia          15.0
# Zimbabwe People's Army (ZIPA)      Rhodesia           0.0
#
# [939 rows x 1 columns]

# %% [markdown]
# Sorting Number of people wounded

# %%
gcw = df[["Group Name","Country","Wounded"]].groupby(["Group Name" , "Country"],axis=0).sum()

# %%
gcw
# Out:
#                                                    Wounded
# Group Name                         Country
# 1st of May Group                   Spain               0.0
#                                    Switzerland         0.0
#                                    United Kingdom      0.0
# 23rd of September Communist League Mexico             14.0
# 28 May Armenian Organization       Turkey             52.0
# ...                                                    ...
# Zimbabwe African People's Union    Zambia              0.0
# Zimbabwe Guerrillas                Rhodesia            2.0
#                                    Zambia              0.0
# Zimbabwe Patriotic Front           Rhodesia            3.0
# Zimbabwe People's Army (ZIPA)      Rhodesia            0.0
#
# [939 rows x 1 columns]

# %%
gcw.head(10).plot(kind="bar", color = "blue" , figsize=(15,6))
plt.title("Countries with most people wounded by a particular group",fontsize=12) 
plt.xlabel("Terrorist Group , Country",fontsize= 12) 
plt.ylabel("Number of people wounded",fontsize= 12)
# Out:
# Text(0, 0.5, 'Number of people wounded')

# %% [markdown]
# ### **9. Humanity affected (World Wide) by terrorist attack from 1970 to 2017**

# %% [markdown]
# 1.total casualties killed + wounded due to terrorist attack

# %%
casualty = df.loc[:,"Casualty"].sum()
print("Print total number of casualties due to terrorist attack :  " , casualty)
# Out:
# Print total number of casualties due to terrorist attack :   14762.0

# %% [markdown]
# 2. killed due to terrorist attack

# %%
kill = df.loc[:,"Killed"].sum()
print("Print total number of casualties due to terrorist attack " , kill)
# Out:
# Print total number of casualties due to terrorist attack  6929.0

# %% [markdown]
# 3. Wounded due to terrorist attack

# %%
wound = df.loc[:,"Wounded"].sum()
print("Print total number of casualties due to terrorist attack " , wound)
# Out:
# Print total number of casualties due to terrorist attack  7833.0
